# %% [markdown]
# # NumPy 1-Hour Quiz — Easy & Medium (Tasks 1–65)
#
# **You have 60 minutes. Answer as many questions as you can.**
#
# ## Rules
#
# - The **only** resource you may use is `numpy-reference.html`, open in a browser
#   beside this notebook. No internet, no AI assistant, no notebooks from class.
# - Each code cell below is one question. Replace the
#   `raise NotImplementedError(...)` line with your NumPy logic and **return** the
#   answer. A printed value does not count — the marker reads what you `return`.
# - **Keep each answer inside its own cell.** Everything `qNNN` needs must live in
#   that one cell. Do not call one question's function from another, and do not
#   rely on a variable, constant, or helper defined in a different cell — the
#   marker lifts each cell out on its own, so anything defined elsewhere will not
#   exist. A helper function is fine as long as you nest it inside `qNNN`.
# - **We grade the function definitions only.** Any loose code in a cell —
#   a `print`, a test call, an assertion, a stray assignment outside the `def` —
#   is ignored and earns nothing. It will not lose you marks either, so leave it
#   if it helps you think.
# - **NumPy only.** Use `np` and the Python standard syntax you already have.
#   Do not import anything else: no `math`, `random`, `statistics`, `pandas`,
#   `scipy`, `itertools`, or `collections`. An answer that needs another import
#   scores zero.
# - **Do not change the function header.** The name and the parameters are the
#   contract. A renamed function or an added, dropped, or reordered parameter
#   scores zero even if the logic inside is right.
# - Read the `Input`, `Returns`, and `Requirement` lines in the docstring. They
#   pin down the shape, the dtype, and the tie-breaking or normalization rule
#   that the marker checks.
# - Do not delete, reorder, merge, or split the question cells. If you want
#   somewhere to experiment, add scratch cells **below the last question**, not
#   between them.
# - Work in **JupyterLab**, from the copy of this file you were given. Do not
#   upload it to Colab and do not paste the questions into another editor or into
#   any online tool — the submission is checked for that, and a notebook that
#   comes back rebuilt rather than filled in is treated as academic misconduct.
# - Skip anything that stalls you. Every question is worth one point, so three
#   easy ones beat one hard one. Come back if time allows.
#
# ## Before the clock starts
#
# 1. Run the import cell below.
# 2. Open `numpy-reference.html` in a browser. Search it by task number, prompt
#    text, NumPy function, or concept.
#
# ## When you are done
#
# Save the notebook and submit this `.ipynb` file. Leave the unanswered questions
# exactly as they are — a stub that still raises `NotImplementedError` costs you
# only that question's point, whereas a half-edited cell that will not parse can
# cost you the whole notebook.
#
# **Test your own work as you go.** Nothing here checks you. Call your function on
# a small input you build yourself, in a scratch cell at the very bottom, and
# confirm the `shape` and `dtype` against the docstring before you move on.

# %%
# Run this cell first. It is not a question.
import numpy as np

print("NumPy", np.__version__)

# %% [markdown]
# ---
#
# ## Easy — Tasks 1–35
#
# One function, one task. Aim to clear this section in about 25 minutes.

# %%
def q001():
    """Task 001 — Create a 1-D array of the integers 0 through 9.

    Input       : No arguments.
    Returns     : NumPy array with shape (10,), integer kind.
    ‌​​​​‌​​​​‌‌​‌​‌
    """
    raise NotImplementedError("q001")

# %%
def q002():
    """Task 002 — Create a 3×3 array of all zeros.

    Input       : No arguments.
    Returns     : NumPy array with shape (3, 3).
    Requirement : Return a 3 x 3 NumPy array of zeros.
    ​​​‌​​‌‌​​​​​‌​‌
    """
    raise NotImplementedError("q002")

# %%
def q003():
    """Task 003 — Create a 4×4 identity matrix.

    Input       : No arguments.
    Returns     : NumPy array with shape (4, 4).
    Requirement : Return a 4 x 4 NumPy identity matrix.
    ‌‌​‌​​​‌‌​‌‌‌​‌‌
    """
    raise NotImplementedError("q003")

# %%
def q004():
    """Task 004 — Create 50 evenly spaced points between 0 and 1, inclusive of both
    ends.

    Input       : No arguments.
    Returns     : NumPy array with shape (50,).
    Requirement : Return exactly 50 evenly spaced values, including 0 and 1.
    ‌‌‌‌​‌​‌‌‌​​​​​‌
    """
    raise NotImplementedError("q004")

# %%
def q005():
    """Task 005 — Create an array of the values 0, 10, 20, …, 100 using a fixed step.

    Input       : No arguments.
    Returns     : NumPy array with shape (11,), integer kind.
    ‌‌‌​‌‌‌​‌‌​‌​​​​
    """
    raise NotImplementedError("q005")

# %%
def q006(x):
    """Task 006 — Reshape a length-12 array into a 3×4 matrix.

    Input       : x: array containing exactly 12 values.
    Returns     : NumPy array with shape (3, 4).
    Requirement : x must contain exactly 12 values; return shape (3, 4).
    ​‌‌​‌​​​‌​​​‌‌‌‌
    """
    raise NotImplementedError("q006")

# %%
def q007(x):
    """Task 007 — Compute the element-wise square root of an array.

    Input       : x: numeric NumPy array of any checked shape.
    Returns     : NumPy array with the same shape as x.
    ​‌​‌​‌​‌​‌‌​‌​​​
    """
    raise NotImplementedError("q007")

# %%
def q008(x):
    """Task 008 — Compute the mean of all elements in an array.

    Input       : x: numeric NumPy array.
    Returns     : Numeric scalar.
    ​‌​​‌‌​‌‌‌​‌‌‌‌‌
    """
    raise NotImplementedError("q008")

# %%
def q009(x):
    """Task 009 — Compute the sum of each column of a 2-D array.

    Input       : x: 2-D numeric array with shape (rows, columns).
    Returns     : 1-D NumPy array with one value per input column.
    ​​​‌​​‌‌‌​​​‌​​‌
    """
    raise NotImplementedError("q009")

# %%
def q010(x):
    """Task 010 — Find the index of the largest element in a 1-D array.

    Input       : x: non-empty 1-D numeric array.
    Returns     : Integer scalar index.
    Requirement : If several elements are tied for the maximum, return the first
                  (smallest) index.
    ​​​‌​​‌​​​​​‌​‌‌
    """
    raise NotImplementedError("q010")

# %%
def q011(x):
    """Task 011 — Transpose a 2-D matrix.

    Input       : x: 2-D array with shape (rows, columns).
    Returns     : NumPy array with shape (columns, rows).
    ​​‌​​‌‌‌​‌‌‌​‌​‌
    """
    raise NotImplementedError("q011")

# %%
def q012(x):
    """Task 012 — Flatten a multi-dimensional array into a 1-D array.

    Input       : x: multi-dimensional NumPy array.
    Returns     : 1-D NumPy array with shape (x.size,).
    ​‌‌‌​‌‌​​​​‌‌‌​‌
    """
    raise NotImplementedError("q012")

# %%
def q013(a, b):
    """Task 013 — Concatenate two 1-D arrays end to end.

    Input       : a, b: 1-D arrays.
    Returns     : 1-D NumPy array with shape (len(a) + len(b),).
    ​‌​​​​‌‌‌‌​‌‌‌‌​
    """
    raise NotImplementedError("q013")

# %%
def q014(a, b):
    """Task 014 — Stack two 1-D arrays as the two rows of a 2-D array.

    Input       : a, b: equal-length 1-D arrays of length n.
    Returns     : 2-D NumPy array with shape (2, n).
    ​‌‌‌‌‌​​​​‌‌‌‌‌​
    """
    raise NotImplementedError("q014")

# %%
def q015(x):
    """Task 015 — Cast a float array to 32-bit integers.

    Input       : x: floating-point NumPy array.
    Returns     : NumPy array with the same shape as x and dtype int32.
    Requirement : The returned NumPy array must have dtype int32.
    ​​‌​​‌‌‌​‌​‌​‌‌‌
    """
    raise NotImplementedError("q015")

# %%
def q016(x):
    """Task 016 — Clip every value in an array to the range [0, 1].

    Input       : x: numeric NumPy array.
    Returns     : NumPy array with the same shape as x.
    ‌​​​‌‌​‌‌​​​​‌‌‌
    """
    raise NotImplementedError("q016")

# %%
def q017(x):
    """Task 017 — Round every element of an array to the nearest integer.

    Input       : x: numeric NumPy array.
    Returns     : NumPy array with the same shape as x.
    Requirement : Halves round to the nearest even integer, as np.round does: 2.5
                  rounds to 2 and 3.5 rounds to 4.
    ‌​​​‌​‌​​​​‌‌​‌​
    """
    raise NotImplementedError("q017")

# %%
def q018(a, b):
    """Task 018 — Compute the dot product of two 1-D vectors.

    Input       : a, b: equal-length 1-D numeric vectors.
    Returns     : Numeric scalar.
    ‌‌​​​‌​​‌​​‌​​​‌
    """
    raise NotImplementedError("q018")

# %%
def q019(x):
    """Task 019 — Sort a 1-D array in ascending order.

    Input       : x: 1-D NumPy array.
    Returns     : 1-D NumPy array with the same shape as x.
    ‌​​‌‌​​​​​​​‌​​‌
    """
    raise NotImplementedError("q019")

# %%
def q020(x):
    """Task 020 — Return the sorted unique values of an array.

    Input       : x: 1-D NumPy array.
    Returns     : 1-D NumPy array with shape (number of unique values,).
    ‌‌​‌​​​​‌​​‌‌‌‌​
    """
    raise NotImplementedError("q020")

# %%
def q021(x):
    """Task 021 — Count how many elements of an array are nonzero.

    Input       : x: NumPy array.
    Returns     : Integer scalar count.
    ‌​​‌‌​‌​‌​​​​​​​
    """
    raise NotImplementedError("q021")

# %%
def q022(x, threshold):
    """Task 022 — Build a boolean mask marking elements greater than a given threshold.

    Input       : x: NumPy array; threshold: scalar threshold.
    Returns     : Boolean NumPy array with the same shape as x.
    ‌‌‌​​​​‌​​​​​​​‌
    """
    raise NotImplementedError("q022")

# %%
def q023(x):
    """Task 023 — Replace every negative value in an array with zero.

    Input       : x: numeric NumPy array.
    Returns     : NumPy array with the same shape as x.
    ‌​​​​‌​​​​‌‌​​​‌
    """
    raise NotImplementedError("q023")

# %%
def q024(x):
    """Task 024 — Compute the cumulative sum of a 1-D array.

    Input       : x: 1-D numeric array of length n.
    Returns     : 1-D NumPy array with shape (n,).
    ‌‌​‌‌‌‌‌​​​‌​‌‌​
    """
    raise NotImplementedError("q024")

# %%
def q025(seed=0):
    """Task 025 — Generate a 3×3 array of uniform random numbers in [0, 1) from a
    seeded generator.

    Input       : seed: integer random seed (default 0).
    Returns     : NumPy array with shape (3, 3).
    Requirement : Use np.random.default_rng(seed); return shape (3, 3).
    ​‌‌​‌‌​‌​‌​​‌​​‌
    """
    raise NotImplementedError("q025")

# %%
def q026(x):
    """Task 026 — Compute the standard deviation of an array.

    Input       : x: numeric NumPy array.
    Returns     : Numeric scalar using population standard deviation (ddof=0).
    ​​‌​​‌​​​​‌​​‌​​
    """
    raise NotImplementedError("q026")

# %%
def q027(x):
    """Task 027 — Find both the minimum and the maximum value of an array.

    Input       : x: non-empty numeric NumPy array.
    Returns     : Two-item tuple (minimum, maximum).
    Requirement : Return a two-item tuple: (minimum, maximum).
    ‌​​​​​‌​‌‌‌​​‌​‌
    """
    raise NotImplementedError("q027")

# %%
def q028(x):
    """Task 028 — Compute the element-wise absolute value of an array.

    Input       : x: real or complex NumPy array.
    Returns     : NumPy array with the same shape as x.
    ​​‌​​‌‌​‌‌‌​‌​‌​
    """
    raise NotImplementedError("q028")

# %%
def q029():
    """Task 029 — Create a 2×4 array filled entirely with the value 7.

    Input       : No arguments.
    Returns     : NumPy array with shape (2, 4).
    ‌​‌​‌​‌​‌‌‌‌‌​‌‌
    """
    raise NotImplementedError("q029")

# %%
def q030(x):
    """Task 030 — Compute the exponential of every element of an array.

    Input       : x: numeric NumPy array.
    Returns     : NumPy array with the same shape as x.
    ​​​‌‌‌​​‌‌​​​‌‌‌
    """
    raise NotImplementedError("q030")

# %%
def q031(x):
    """Task 031 — Reverse the order of a 1-D array.

    Input       : x: 1-D NumPy array of length n.
    Returns     : 1-D NumPy array with shape (n,).
    ‌​​‌​​‌​​‌‌​‌​‌​
    """
    raise NotImplementedError("q031")

# %%
def q032(x):
    """Task 032 — Compute the natural logarithm of every element of an array.

    Input       : x: positive numeric NumPy array.
    Returns     : NumPy array with the same shape as x.
    ‌‌‌​​​​​‌‌​​‌‌‌‌
    """
    raise NotImplementedError("q032")

# %%
def q033(x):
    """Task 033 — Turn a length-n vector into an n×1 column vector by adding an axis.

    Input       : x: 1-D vector of length n.
    Returns     : 2-D NumPy array with shape (n, 1).
    ​‌‌​​‌‌‌​‌​​‌‌​​
    """
    raise NotImplementedError("q033")

# %%
def q034(x):
    """Task 034 — Compute the trace (sum of the diagonal) of a square matrix.

    Input       : x: square 2-D matrix with shape (n, n).
    Returns     : Numeric scalar.
    ​‌‌‌‌‌​‌​‌​​​​​‌
    """
    raise NotImplementedError("q034")

# %%
def q035(x):
    """Task 035 — Return an array in which each element is repeated three consecutive
    times.

    Input       : x: 1-D array of length n.
    Returns     : 1-D NumPy array with shape (3n,).
    Requirement : Return an array with each value repeated three consecutive times.
    ​​‌​‌‌​‌‌​‌​‌‌‌‌
    """
    raise NotImplementedError("q035")

# %% [markdown]
# ---
#
# ## Medium — Tasks 36–65
#
# Chain two or three functions. Read the `Requirement` line carefully: most of the
# marks lost here are lost to an axis, a `ddof`, or a normalization convention.

# %%
def q036(x):
    """Task 036 — Standardize a 1-D array to zero mean and unit standard deviation.

    Input       : x: 1-D numeric array of length n with non-zero standard deviation.
    Returns     : 1-D NumPy array with shape (n,).
    ​​‌​‌​‌​​‌​​​​​‌
    """
    raise NotImplementedError("q036")

# %%
def q037(x):
    """Task 037 — Normalize each row of a matrix so that its entries sum to 1.

    Input       : x: 2-D numeric array; every checked row has a non-zero sum.
    Returns     : 2-D NumPy array with the same shape as x.
    Requirement : Normalize across axis 1. Test rows have non-zero sums.
    ‌‌‌​​​‌​‌​‌​‌‌‌‌
    """
    raise NotImplementedError("q037")

# %%
def q038(x):
    """Task 038 — Min–max scale each column of a matrix independently to the range [0,
    1].

    Input       : x: 2-D numeric array with shape (rows, columns).
    Returns     : 2-D NumPy array with the same shape as x.
    Requirement : Scale columns independently; a constant column maps to zeros.
    ​​​‌‌​‌​​‌‌‌‌‌​‌
    """
    raise NotImplementedError("q038")

# %%
def q039(x):
    """Task 039 — Compute the L2 norm of every row of a matrix.

    Input       : x: 2-D numeric array with shape (rows, features).
    Returns     : 1-D NumPy array with shape (rows,).
    ​​‌​‌​‌‌‌‌‌​‌‌​‌
    """
    raise NotImplementedError("q039")

# %%
def q040(x, k):
    """Task 040 — Return the k largest values of an array, in descending order.

    Input       : x: 1-D array of length n; k: integer with 0 <= k <= n.
    Returns     : 1-D NumPy array with shape (k,).
    Requirement : Return the k largest values in descending order.
    ‌​‌​‌​​‌​‌​​​​‌‌
    """
    raise NotImplementedError("q040")

# %%
def q041(labels, num_classes):
    """Task 041 — One-hot encode a vector of integer class labels into a 2-D array.

    Input       : labels: length-n integer vector in [0, num_classes); num_classes:
                  positive integer.
    Returns     : 2-D NumPy array with shape (n, num_classes).
    Requirement : Return shape (len(labels), num_classes).
    ​‌‌‌‌​​‌‌‌‌​​‌‌​
    """
    raise NotImplementedError("q041")

# %%
def q042(x, window):
    """Task 042 — Compute a simple moving average of a 1-D signal with a fixed window
    length.

    Input       : x: length-n 1-D signal; window: integer with 1 <= window <= n.
    Returns     : 1-D NumPy array with shape (n - window + 1,).
    Requirement : Return only complete windows ('valid' mode).
    ​​‌​​​‌‌​​​​‌​‌‌
    """
    raise NotImplementedError("q042")

# %%
def q043(x):
    """Task 043 — Replace the NaNs in each column of a matrix with that column's mean
    of the non-NaN values.

    Input       : x: 2-D floating-point array that may contain NaNs.
    Returns     : 2-D NumPy array with the same shape as x.
    Requirement : Use each column's non-NaN mean; an all-NaN column remains NaN.
    ​‌‌​‌‌​‌‌​‌‌​‌​‌
    """
    raise NotImplementedError("q043")

# %%
def q044(x):
    """Task 044 — Compute the softmax of a 1-D vector.

    Input       : x: non-empty 1-D numeric vector.
    Returns     : 1-D NumPy array with the same shape as x.
    Requirement : Use a numerically stable softmax (subtract the maximum first).
    ​​​‌‌​‌​‌‌‌‌​‌‌​
    """
    raise NotImplementedError("q044")

# %%
def q045(x, bins, value_range=None):
    """Task 045 — Bin continuous data into a histogram and return the counts per bin.

    Input       : x: 1-D data; bins: count or explicit edges; value_range: optional
                  (low, high).
    Returns     : Integer counts: shape (bins,) or (len(edges) - 1,).
    Requirement : Return histogram counts only. value_range is passed to
                  np.histogram.
    ​​​‌‌‌‌​​‌​​​‌‌‌
    """
    raise NotImplementedError("q045")

# %%
def q046(x):
    """Task 046 — Compute the correlation-coefficient matrix of a data matrix and
    extract its off-diagonal entries.

    Input       : x: 2-D data matrix with shape (samples, variables).
    Returns     : 1-D NumPy array with shape (variables * (variables - 1) / 2,).
    Requirement : Rows are samples and columns are variables; return upper-triangle
                  off-diagonal correlations in row-major order.
    ‌‌‌‌​‌‌​‌‌​​‌​​‌
    """
    raise NotImplementedError("q046")

# %%
def q047(x, threshold):
    """Task 047 — Select and return only the rows of a matrix whose first column
    exceeds a threshold.

    Input       : x: 2-D matrix with shape (rows, columns); threshold: scalar.
    Returns     : 2-D NumPy array with shape (matching rows, columns).
    ‌​‌‌​‌​‌​‌‌​‌​‌​
    """
    raise NotImplementedError("q047")

# %%
def q048(a, b):
    """Task 048 — Compute the Euclidean distance between two vectors.

    Input       : a, b: numeric vectors with the same shape.
    Returns     : Numeric scalar.
    ​‌​​‌​‌​‌‌‌​​​‌‌
    """
    raise NotImplementedError("q048")

# %%
def q049(image):
    """Task 049 — Convert a uint8 image array in [0, 255] to a float32 array in [0, 1].

    Input       : image: uint8 NumPy array with values in [0, 255].
    Returns     : NumPy array with the same shape as image and dtype float32.
    Requirement : The returned NumPy array must have dtype float32.
    ​​‌‌​​​‌‌​‌‌‌​‌​
    """
    raise NotImplementedError("q049")

# %%
def q050(images):
    """Task 050 — Flatten a batch of images with shape (N, H, W) into a 2-D matrix of
    shape (N, H·W).

    Input       : images: image batch with shape (N, H, W).
    Returns     : 2-D NumPy array with shape (N, H * W).
    ‌​​​​‌‌‌‌‌‌​​‌‌​
    """
    raise NotImplementedError("q050")

# %%
def q051(x):
    """Task 051 — Compute the mean of an array while ignoring NaNs, and separately
    report how many values were NaN.

    Input       : x: NumPy array that may contain NaNs.
    Returns     : Two-item tuple (NaN-ignoring mean, NaN count).
    Requirement : Return a two-item tuple: (mean ignoring NaNs, number of NaNs).
    ​​‌​​‌‌​‌​‌‌‌‌‌​
    """
    raise NotImplementedError("q051")

# %%
def q052(x):
    """Task 052 — Add a bias column of ones to a feature matrix to form a design
    matrix.

    Input       : x: feature matrix with shape (N, F).
    Returns     : 2-D NumPy array with shape (N, F + 1).
    Requirement : Append the bias column as the final column.
    ​​‌‌​‌​‌​​​​​‌‌‌
    """
    raise NotImplementedError("q052")

# %%
def q053(x):
    """Task 053 — Given a 2-D array with samples in rows, center each column and
    compute the sample covariance matrix by hand using N−1.

    Input       : x: data matrix with shape (N, F), samples in rows, N >= 2.
    Returns     : 2-D NumPy array with shape (F, F).
    Requirement : Rows are samples. Center each column and divide centered.T @
                  centered by n - 1.
    ​​​‌‌‌​​‌‌​​​‌​‌
    """
    raise NotImplementedError("q053")

# %%
def q054(keys, values):
    """Task 054 — Compute the indices that sort one array, then use them to reorder a
    second array.

    Input       : keys: length-n 1-D array; values: array whose first axis has
                  length n.
    Returns     : NumPy array with the same shape as values.
    Requirement : Use a stable ordering when keys are tied.
    ‌‌​‌​​​‌‌​​‌​​‌‌
    """
    raise NotImplementedError("q054")

# %%
def q055(values, weights):
    """Task 055 — Given per-item values and weights, compute their weighted average.

    Input       : values, weights: compatible numeric arrays with non-zero total
                  weight.
    Returns     : Numeric scalar.
    ‌‌​​‌​‌‌​‌‌​‌​‌​
    """
    raise NotImplementedError("q055")

# %%
def q056(x):
    """Task 056 — Find the indices of all elements lying more than three standard
    deviations from the mean.

    Input       : x: 1-D numeric array of length n.
    Returns     : 1-D integer index array with shape (number of outliers,).
    Requirement : Return 1-D indices satisfying the strict condition abs(x - mean) >
                  3 * std.
    ​​​‌​‌‌‌‌​​‌‌​‌‌
    """
    raise NotImplementedError("q056")

# %%
def q057(a, b):
    """Task 057 — Compute the cosine similarity between every pair of rows drawn from
    two matrices.

    Input       : a: shape (r, d); b: shape (s, d); rows are vectors.
    Returns     : 2-D NumPy array with shape (r, s).
    Requirement : Rows are vectors. Pairwise similarity involving a zero vector is
                  defined as 0.
    ​‌‌‌‌‌​​​‌‌‌​‌​​
    """
    raise NotImplementedError("q057")

# %%
def q058(x, block_size):
    """Task 058 — Downsample a 1-D signal by averaging consecutive non-overlapping
    blocks.

    Input       : x: length-n 1-D signal; block_size: positive integer dividing n.
    Returns     : 1-D NumPy array with shape (n / block_size,).
    Requirement : block_size must be positive and divide len(x); otherwise raise
                  ValueError.
    ​​​‌​‌‌​​​‌‌​‌‌‌
    """
    raise NotImplementedError("q058")

# %%
def q059(predicted, truth):
    """Task 059 — Given predicted and true binary labels, count the true positives,
    false positives, true negatives, and false negatives.

    Input       : predicted, truth: same-shape vectors of binary labels.
    Returns     : Four-item tuple of integer counts (TP, FP, TN, FN).
    Requirement : Return (true positives, false positives, true negatives, false
                  negatives).
    ‌​‌​​‌​‌​​‌‌‌​‌‌
    """
    raise NotImplementedError("q059")

# %%
def q060(x):
    """Task 060 — Linearly interpolate the missing (NaN) values in a 1-D array from
    their neighbors.

    Input       : x: length-n 1-D array containing at least one non-NaN value.
    Returns     : 1-D NumPy array with shape (n,).
    Requirement : Use NumPy interpolation; endpoint NaNs take the nearest known
                  endpoint value.
    ​‌​​‌‌​‌‌​‌‌‌​​‌
    """
    raise NotImplementedError("q060")

# %%
def q061(x, window):
    """Task 061 — Compute a rolling standard deviation over a fixed window using a
    sliding-window view.

    Input       : x: length-n 1-D signal; window: integer with 1 <= window <= n.
    Returns     : 1-D NumPy array with shape (n - window + 1,).
    Requirement : Return population standard deviation (ddof=0) for complete
                  windows.
    ​​​​‌​​‌​‌‌​​​‌​
    """
    raise NotImplementedError("q061")

# %%
def q062(x, train_fraction=0.7, seed=0):
    """Task 062 — Split a dataset into a training and test set by randomly permuting
    the row indices.

    Input       : x: dataset with N rows; train_fraction in [0, 1]; seed: integer.
    Returns     : Two-item tuple (train, test), preserving all dimensions after the
                  row axis.
    Requirement : Use a local default_rng(seed). Permute rows, then split at int(n *
                  train_fraction); return (train, test).
    ​​‌‌​‌‌​‌‌​‌‌​‌‌
    """
    raise NotImplementedError("q062")

# %%
def q063(x):
    """Task 063 — Rescale a vector so that its values sum to exactly 1 (turn counts
    into a probability distribution).

    Input       : x: length-n numeric vector with a non-zero sum.
    Returns     : 1-D NumPy array with shape (n,).
    Requirement : Inputs used for checking have a non-zero total.
    ​​​‌‌​‌​‌​​‌‌​‌‌
    """
    raise NotImplementedError("q063")

# %%
def q064(x):
    """Task 064 — Given a 2-D array, subtract its global mean and divide by its global
    standard deviation.

    Input       : x: 2-D numeric array with non-zero global standard deviation.
    Returns     : 2-D NumPy array with the same shape as x.
    Requirement : Use the global mean and population standard deviation (ddof=0).
    ‌​​​‌‌‌‌‌‌​​​​‌​
    """
    raise NotImplementedError("q064")

# %%
def q065(a, b):
    """Task 065 — Keep only the elements common to two integer arrays and return them
    sorted.

    Input       : a, b: 1-D integer arrays.
    Returns     : 1-D integer array with shape (number of unique common values,).
    ‌‌​‌​​‌​‌‌​​​‌​‌
    """
    raise NotImplementedError("q065")

# %% [markdown]
# ---
#
# ## End of quiz
#
# That is all 65 questions. Save the notebook and submit the `.ipynb` file.
#
# Anything you add below this line is scratch work and is not marked.
